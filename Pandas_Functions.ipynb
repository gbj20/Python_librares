# %% [markdown]
# <a href="https://colab.research.google.com/github/gbj20/Python_librares/blob/main/Pandas_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data.csv")
df
# Out:
#   Unnamed: 0 state  color    food  age  height  score
# 0       Jane    NY   blue   Steak   30     165    4.6
# 1       Niko    TX  green    Lamb    2      70    8.3
# 2      Aaron    FL    red   Mango   12     120    9.0
# 3   Penelope    AL  white   Apple    4      80    3.3
# 4       Dean    AK   gray  Cheese   32     180    1.8
# 5  Christina    TX  black   Melon   33     172    9.5
# 6   Cornelia    TX    red   Beans   69     150    2.2

# %%
df.shape
# Out:
# (7, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7 non-null      object
#  1   state       7 non-null      object
#  2   color       7 non-null      object
#  3   food        7 non-null      object
#  4   age         7 non-null      int64
#  5   height      7 non-null      int64
#  6   score       7 non-null      float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 520.0+ bytes

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'state', 'color', 'food', 'age', 'height', 'score'], dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# state          object
# color          object
# food           object
# age             int64
# height          int64
# score         float64
# dtype: object

# %%
df.describe()
# Out:
#              age      height     score
# count   7.000000    7.000000  7.000000
# mean   26.000000  133.857143  5.528571
# std    23.115651   44.693134  3.324512
# min     2.000000   70.000000  1.800000
# 25%     8.000000  100.000000  2.750000
# 50%    30.000000  150.000000  4.600000
# 75%    32.500000  168.500000  8.650000
# max    69.000000  180.000000  9.500000

# %%
df.rename(columns= {'Unnamed: 0' : 'Names'},inplace = True)

# %%
df
# Out:
#        Names state  color    food  age  height  score
# 0       Jane    NY   blue   Steak   30     165    4.6
# 1       Niko    TX  green    Lamb    2      70    8.3
# 2      Aaron    FL    red   Mango   12     120    9.0
# 3   Penelope    AL  white   Apple    4      80    3.3
# 4       Dean    AK   gray  Cheese   32     180    1.8
# 5  Christina    TX  black   Melon   33     172    9.5
# 6   Cornelia    TX    red   Beans   69     150    2.2

# %%
df.drop(columns = ['state'],inplace=True)

# %%
df
# Out:
#        Names  color    food  age  height  score
# 0       Jane   blue   Steak   30     165    4.6
# 1       Niko  green    Lamb    2      70    8.3
# 2      Aaron    red   Mango   12     120    9.0
# 3   Penelope  white   Apple    4      80    3.3
# 4       Dean   gray  Cheese   32     180    1.8
# 5  Christina  black   Melon   33     172    9.5
# 6   Cornelia    red   Beans   69     150    2.2

# %%
df.head()
# Out:
#       Names  color    food  age  height  score
# 0      Jane   blue   Steak   30     165    4.6
# 1      Niko  green    Lamb    2      70    8.3
# 2     Aaron    red   Mango   12     120    9.0
# 3  Penelope  white   Apple    4      80    3.3
# 4      Dean   gray  Cheese   32     180    1.8

# %%
df.tail(3)
# Out:
#        Names  color    food  age  height  score
# 4       Dean   gray  Cheese   32     180    1.8
# 5  Christina  black   Melon   33     172    9.5
# 6   Cornelia    red   Beans   69     150    2.2

# %%
df.sample()
# Out:
#       Names color   food  age  height  score
# 6  Cornelia   red  Beans   69     150    2.2

# %%
df.query('age > 30')
# Out:
#        Names  color    food  age  height  score
# 4       Dean   gray  Cheese   32     180    1.8
# 5  Christina  black   Melon   33     172    9.5
# 6   Cornelia    red   Beans   69     150    2.2

# %%
df.loc[5, 'Names']   #[row,column]
# Out:
# 'Christina'

# %%
df.iloc[[1, 2],[5,3]]
# Out:
#    score  age
# 1    8.3    2
# 2    9.0   12

# %%
df["color"].unique()
# Out:
# array(['blue', 'green', 'red', 'white', 'gray', 'black'], dtype=object)

# %%
df.nunique()
# Out:
# Names     7
# color     6
# food      7
# age       7
# height    7
# score     7
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Names     0
# color     0
# food      0
# age       0
# height    0
# score     0
# dtype: int64

# %%
df.sort_values("height")
# Out:
#        Names  color    food  age  height  score
# 1       Niko  green    Lamb    2      70    8.3
# 3   Penelope  white   Apple    4      80    3.3
# 2      Aaron    red   Mango   12     120    9.0
# 6   Cornelia    red   Beans   69     150    2.2
# 0       Jane   blue   Steak   30     165    4.6
# 5  Christina  black   Melon   33     172    9.5
# 4       Dean   gray  Cheese   32     180    1.8

# %%
df.value_counts("color")
# Out:
# color
# red      2
# black    1
# blue     1
# gray     1
# green    1
# white    1
# Name: count, dtype: int64

# %%
df.nlargest(4, "age")
# Out:
#        Names  color    food  age  height  score
# 6   Cornelia    red   Beans   69     150    2.2
# 5  Christina  black   Melon   33     172    9.5
# 4       Dean   gray  Cheese   32     180    1.8
# 0       Jane   blue   Steak   30     165    4.6

# %%
df.nsmallest(3, "height")
# Out:
#       Names  color   food  age  height  score
# 1      Niko  green   Lamb    2      70    8.3
# 3  Penelope  white  Apple    4      80    3.3
# 2     Aaron    red  Mango   12     120    9.0

# %%
condition = df["color"] == "red"
df.where(condition)
# Out:
#       Names color   food   age  height  score
# 0       NaN   NaN    NaN   NaN     NaN    NaN
# 1       NaN   NaN    NaN   NaN     NaN    NaN
# 2     Aaron   red  Mango  12.0   120.0    9.0
# 3       NaN   NaN    NaN   NaN     NaN    NaN
# 4       NaN   NaN    NaN   NaN     NaN    NaN
# 5       NaN   NaN    NaN   NaN     NaN    NaN
# 6  Cornelia   red  Beans  69.0   150.0    2.2

# %%
df[["age","height"]].corr() #used to find out pairwise correlations between all the columns of the DataFrame
# Out:
#              age    height
# age     1.000000  0.689503
# height  0.689503  1.000000

# %%
# Select only numeric columns before calculating correlations
df_numeric = df.select_dtypes(include=['number'])
df_numeric.corr()
# Out:
#              age    height     score
# age     1.000000  0.689503 -0.450021
# height  0.689503  1.000000 -0.233620
# score  -0.450021 -0.233620  1.000000
